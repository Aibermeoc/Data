# %%
from git import Repo

# Configura tus credenciales de GitHub (esto es solo un ejemplo, asegúrate de manejar tus credenciales de forma segura)
git_url = 'https://github.com/usuario/repositorio.git'
repo_dir = '/path/to/your/local/directory'

# Clonar un repositorio de GitHub a una ubicación local especificada
Repo.clone_from(git_url, repo_dir)
